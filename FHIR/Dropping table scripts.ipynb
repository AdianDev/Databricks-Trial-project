-- %% [markdown]
-- For droping Tables from Raw

-- %%
DROP TABLE IF EXISTS raw.fhir.condition;
DROP TABLE IF EXISTS raw.fhir.patient;
DROP TABLE IF EXISTS raw.fhir.observation;
DROP TABLE IF EXISTS raw.fhir.encounter;

-- %% [markdown]
-- For droping Tables from Bronze

-- %%
DROP TABLE IF EXISTS bronze.fhir.condition;
DROP TABLE IF EXISTS bronze.fhir.patient;
DROP TABLE IF EXISTS bronze.fhir.observation;
DROP TABLE IF EXISTS bronze.fhir.encounter;

-- %% [markdown]
-- For droping Tables from Silver

-- %%
DROP TABLE IF EXISTS silver.fhir.condition;
DROP TABLE IF EXISTS silver.fhir.patient;
DROP TABLE IF EXISTS silver.fhir.observation;
DROP TABLE IF EXISTS silver.fhir.encounter;

-- %%
DROP TABLE IF EXISTS gold.fhir.dim_encounter;
DROP TABLE IF EXISTS gold.fhir.dim_patient;
DROP TABLE IF EXISTS gold.fhir.fact_condition;
DROP TABLE IF EXISTS gold.fhir.fact_encounter;
DROP TABLE IF EXISTS gold.fhir.fact_observation;
